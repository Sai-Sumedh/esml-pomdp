# %% [markdown]
# # Plot estimate from the algorithm $\hat{\theta}$ vs true $\theta^*$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math, time
from functions_queueing_system import *
from functions_extremum_seeking import *
import random

# %%
seed_val=2
np.random.seed(seed_val)
random.seed(seed_val)

# %%
M = 100
K = 50
T = 200000

dep_rate = [0.3, 0.6]
eps = 1
gamma = 0.1
alpha = 1
beta = 0.9
avg_over = 100
A = 0.01
B = 10 #was 10 before

# %%
random.seed(0)
np.random.seed(0)
tic = time.time()
temp = estimate_theta_es(0.1, theta_star=0.4, M=M, K=K, T=T,alpha=alpha, beta=beta, \
                         gamma=gamma, eps=eps, dep_rate=dep_rate, A=A, B=B)
toc = time.time()
print(f"{toc-tic}s")
# Out:
# 121.2916111946106s

# %%
plt.plot(temp['theta_hat_t'])
plt.hlines(0.4, 0, T, linestyles='dashed', colors='k')

# %% [markdown]
# # Test performance on multiple runs

# %%
num_true_vals = 20
num_init_vals = 5
# theta_init_all = np.linspace(1e-3, 1-1e-3, num=num_init_vals)
theta_init_all = np.random.rand(num_init_vals)
results_all = [[None]*num_init_vals for _ in range(num_true_vals)] #made a change to save results properly, need to run it at some point (do it in the evening today)
theta_hat_t_all = np.zeros((T, num_init_vals, num_true_vals))
theta_hat_mean_all = np.zeros((num_true_vals,))
theta_star_all = np.linspace(1e-3, 1-1e-3, num=num_true_vals)

# %%
int(num_true_vals/2)
# Out:
# 10

# %%
random.seed(0)
np.random.seed(0)

#first half
start = 0
end = int(num_true_vals/2)

#second half
# start = int(num_true_vals/2)
# end = num_true_vals

tic = time.time()
for j in range(start, end):
    theta_star_j = theta_star_all[j]
    for i in range(num_init_vals):
        results_all[j][i] = estimate_theta_es(theta_init_all[i], theta_star=theta_star_j, M=M, K=K, T=T,\
                                              alpha=alpha, beta=beta, gamma=gamma, eps=eps, dep_rate=dep_rate, A=A, B=B)
        theta_hat_t_all[:,i,j] = results_all[j][i]['theta_hat_t']
        print(f"theta_star={theta_star_j} run={i+1} done")
        with open('status_firsthalf.txt', 'w+') as f:
            f.write(f"theta_star={theta_star_j} ({j+1-start}/{end-start}) run={i+1}/{num_init_vals} done in {time.perf_counter()-tic}s")
    if (j+1)%5==0 or j==num_true_vals-1:
        np.savez('./results/algo_performance_qs_first-'+str(j+1)+'.npz', M=M, K=K, T=T, \
             dep_rate=dep_rate, eps=eps, gamma=gamma, alpha=alpha, beta=beta, avg_over=avg_over,\
            num_init_vals= num_init_vals, num_true_vals=num_true_vals, theta_init_all=theta_init_all, \
            results_all=results_all, theta_hat_t_all=theta_hat_t_all, theta_hat_mean_all=theta_hat_mean_all,\
            theta_star_all=theta_star_all)
    print(f"theta_star={theta_star_j} done")
    theta_hat_mean_all[j] = np.mean(np.mean(theta_hat_t_all[-avg_over:,:,j], axis=0)) #average over the last 200 steps
toc = time.time()
print(f"time={toc-tic}s")
# Out:
# theta_star=0.001 run=1 done
# theta_star=0.001 run=2 done
# theta_star=0.001 run=3 done
# theta_star=0.001 run=4 done
# theta_star=0.001 run=5 done
# theta_star=0.001 done
# theta_star=0.053526315789473686 run=1 done
# theta_star=0.053526315789473686 run=2 done
# theta_star=0.053526315789473686 run=3 done
# theta_star=0.053526315789473686 run=4 done
# theta_star=0.053526315789473686 run=5 done
# theta_star=0.053526315789473686 done
# theta_star=0.10605263157894737 run=1 done
# theta_star=0.10605263157894737 run=2 done
# theta_star=0.10605263157894737 run=3 done
# theta_star=0.10605263157894737 run=4 done
# theta_star=0.10605263157894737 run=5 done
# theta_star=0.10605263157894737 done
# theta_star=0.15857894736842104 run=1 done
# theta_star=0.15857894736842104 run=2 done
# theta_star=0.15857894736842104 run=3 done
# theta_star=0.15857894736842104 run=4 done
# theta_star=0.15857894736842104 run=5 done
# theta_star=0.15857894736842104 done
# theta_star=0.21110526315789474 run=1 done
# theta_star=0.21110526315789474 run=2 done
# theta_star=0.21110526315789474 run=3 done
# theta_star=0.21110526315789474 run=4 done
# theta_star=0.21110526315789474 run=5 done
# theta_star=0.21110526315789474 done
# theta_star=0.26363157894736844 run=1 done
# theta_star=0.26363157894736844 run=2 done
# theta_star=0.26363157894736844 run=3 done
# theta_star=0.26363157894736844 run=4 done
# theta_star=0.26363157894736844 run=5 done
# theta_star=0.26363157894736844 done
# theta_star=0.3161578947368421 run=1 done
# theta_star=0.3161578947368421 run=2 done
# theta_star=0.3161578947368421 run=3 done
# theta_star=0.3161578947368421 run=4 done
# theta_star=0.3161578947368421 run=5 done
# theta_star=0.3161578947368421 done
# theta_star=0.3686842105263158 run=1 done
# theta_star=0.3686842105263158 run=2 done
# theta_star=0.3686842105263158 run=3 done
# theta_star=0.3686842105263158 run=4 done
# theta_star=0.3686842105263158 run=5 done
# theta_star=0.3686842105263158 done
# theta_star=0.4212105263157895 run=1 done
# theta_star=0.4212105263157895 run=2 done
# theta_star=0.4212105263157895 run=3 done
# theta_star=0.4212105263157895 run=4 done
# theta_star=0.4212105263157895 run=5 done
# theta_star=0.4212105263157895 done
# theta_star=0.4737368421052632 run=1 done
# theta_star=0.4737368421052632 run=2 done
# theta_star=0.4737368421052632 run=3 done
# theta_star=0.4737368421052632 run=4 done
# theta_star=0.4737368421052632 run=5 done
# theta_star=0.4737368421052632 done
# theta_star=0.5262631578947369 run=1 done
# theta_star=0.5262631578947369 run=2 done
# theta_star=0.5262631578947369 run=3 done
# theta_star=0.5262631578947369 run=4 done
# theta_star=0.5262631578947369 run=5 done
# theta_star=0.5262631578947369 done
# theta_star=0.5787894736842105 run=1 done
# theta_star=0.5787894736842105 run=2 done
# theta_star=0.5787894736842105 run=3 done
# theta_star=0.5787894736842105 run=4 done
# theta_star=0.5787894736842105 run=5 done
# theta_star=0.5787894736842105 done
# theta_star=0.6313157894736842 run=1 done
# theta_star=0.6313157894736842 run=2 done
# theta_star=0.6313157894736842 run=3 done
# theta_star=0.6313157894736842 run=4 done
# theta_star=0.6313157894736842 run=5 done
# theta_star=0.6313157894736842 done
# theta_star=0.6838421052631579 run=1 done
# theta_star=0.6838421052631579 run=2 done
# theta_star=0.6838421052631579 run=3 done
# theta_star=0.6838421052631579 run=4 done
# theta_star=0.6838421052631579 run=5 done
# theta_star=0.6838421052631579 done
# theta_star=0.7363684210526316 run=1 done
# theta_star=0.7363684210526316 run=2 done
# theta_star=0.7363684210526316 run=3 done
# theta_star=0.7363684210526316 run=4 done
# theta_star=0.7363684210526316 run=5 done
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [8], in <cell line: 5>()
#      11     print(f"theta_star={theta_star_j} run={i+1} done")
#      12 if (j+1)%5==0 or j==num_true_vals-1:
# ---> 13     np.savez('./results/algo_performance_qs_first-'+str(j+1)+'.npz', M=M, K=K, T=T, \
#      14          dep_rate=dep_rate, eps=eps, gamma=gamma, alpha=alpha, beta=beta, avg_over=avg_over,\
#      15         num_init_vals= num_init_vals, num_true_vals=num_true_vals, theta_init_all=theta_init_all, \
#      16         results_all=results_all, theta_hat_t_all=theta_hat_t_all, theta_hat_mean_all=theta_hat_mean_all,\
#      17         theta_star_all=theta_star_all)
#      18 print(f"theta_star={theta_star_j} done")
#      19 theta_hat_mean_all[j] = np.mean(np.mean(theta_hat_t_all[-avg_over:,:,j], axis=0)) #average over the last 200 steps
#
# File <__array_function__ internals>:180, in savez(*args, **kwargs)
#
# File ~\miniconda3\envs\ddp\lib\site-packages\numpy\lib\npyio.py:595, in savez(file, *args, **kwds)
#     511 @array_function_dispatch(_savez_dispatcher)
#     512 def savez(file, *args, **kwds):
#     513     """Save several arrays into a single file in uncompressed ``.npz`` format.
#     514
#     515     Provide arrays as keyword arguments to store them under the
#    (...)
#     593
#     594     """
# --> 595     _savez(file, args, kwds, False)
#
# File ~\miniconda3\envs\ddp\lib\site-packages\numpy\lib\npyio.py:699, in _savez(file, args, kwds, compress, allow_pickle, pickle_kwargs)
#     697     # always force zip64, gh-10776
#     698     with zipf.open(fname, 'w', force_zip64=True) as fid:
# --> 699         format.write_array(fid, val,
#     700                            allow_pickle=allow_pickle,
#     701                            pickle_kwargs=pickle_kwargs)
#     703 zipf.close()
#
# File ~\miniconda3\envs\ddp\lib\site-packages\numpy\lib\format.py:678, in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     676     if pickle_kwargs is None:
#     677         pickle_kwargs = {}
# --> 678     pickle.dump(array, fp, protocol=3, **pickle_kwargs)
#     679 elif array.flags.f_contiguous and not array.flags.c_contiguous:
#     680     if isfileobj(fp):
#
# MemoryError:

# %%
for j in range(num_true_vals):
    plt.scatter([theta_star_all[j]]*num_init_vals, np.mean(theta_hat_t_all[-avg_over:,:,j], axis=0))
plt.plot(theta_star_all, theta_star_all, '--', label="y=x")
plt.plot(theta_star_all, theta_hat_mean_all, 'k*', label=r"$\hat{\theta}$")
plt.xlabel(r"$\theta^*$")
plt.vlines(dep_rate, 0, 1, linestyles='dashed', label="dep_rate", colors='gray')
plt.ylabel(r"parameter estimate $\hat{\theta}$")
plt.title(r"$\hat{\theta}$ vs $\theta^*$: Queueing System")
plt.legend()

# %%
plt.plot(theta_star_all, theta_hat_mean_all, '*', label=r"$\hat{\theta}$")
plt.plot(theta_star_all, theta_star_all, '--', label="y=x")
plt.vlines(dep_rate, 0, 1, linestyles='dashed', label="dep_rate", colors='k')
plt.xlabel(r"$\theta^*$")
plt.ylabel(r"parameter estimate from the algorithm $\hat{\theta}$")
plt.legend()

# %%
k = 0
for i in range(num_init_vals):
    plt.plot(theta_hat_t_all[:,i,k])
plt.hlines(theta_star_all[k], 0, T, linestyles='dashed', colors='k')

# %%
k = 10
plt.plot(results_all[k][i]['X'])
plt.title(r"$\theta^*=$"+str(round(theta_star_all[k], 3)))
plt.ylabel("X")
plt.xlabel("time t")
# Out:
# Text(0.5, 0, 'time t')

# %%
# np.savez('./results/algo_ performance_qs.npz', M=M, K=K, T=T, \
#          dep_rate=dep_rate, eps=eps, gamma=gamma, alpha=alpha, beta=beta, avg_over=avg_over,\
#         num_init_vals= num_init_vals, num_true_vals=num_true_vals, theta_init_all=theta_init_all, \
#         results_all=results_all, theta_hat_t_all=theta_hat_t_all, theta_hat_mean_all=theta_hat_mean_all,\
#         theta_star_all=theta_star_all)
